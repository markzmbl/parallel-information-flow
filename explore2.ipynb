# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1_718
m = 10

# %%
iar = (
    np.fromfile(f'threads_1_simulations_{m}.bin', dtype=np.float32) / m
).reshape((n, n))

# %%
plt.imshow(counts)
